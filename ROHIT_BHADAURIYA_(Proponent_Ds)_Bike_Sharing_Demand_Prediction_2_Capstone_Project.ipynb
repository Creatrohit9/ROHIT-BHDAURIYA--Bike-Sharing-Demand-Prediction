# %% [markdown]
# <a href="https://colab.research.google.com/github/Creatrohit9/ROHIT-BHDAURIYA--Bike-Sharing-Demand-Prediction/blob/main/ROHIT_BHADAURIYA_(Proponent_Ds)_Bike_Sharing_Demand_Prediction_2_Capstone_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Group members :***
#
# # Arunesh Tamboli
#
# # Rohit Bhadauriya

# %% [markdown]
# # <b><u> Project Title : Seoul Bike Sharing Demand Prediction </u></b>

# %% [markdown]
# ## <b> Problem Description </b>
#
# ### Currently Rental bikes are introduced in many urban cities for the enhancement of mobility comfort. It is important to make the rental bike available and accessible to the public at the right time as it lessens the waiting time. Eventually, providing the city with a stable supply of rental bikes becomes a major concern. The crucial part is the prediction of bike count required at each hour for the stable supply of rental bikes.

# %% [markdown]
# ## <b> Data Description </b>
#
# ### <b> The dataset contains weather information (Temperature, Humidity, Windspeed, Visibility, Dewpoint, Solar radiation, Snowfall, Rainfall), the number of bikes rented per hour and date information.</b>
#
#
# ### <b>Attribute Information: </b>
#
# * ### Date : year-month-day
# * ### Rented Bike count - Count of bikes rented at each hour
# * ### Hour - Hour of he day
# * ### Temperature-Temperature in Celsius
# * ### Humidity - %
# * ### Windspeed - m/s
# * ### Visibility - 10m
# * ### Dew point temperature - Celsius
# * ### Solar radiation - MJ/m2
# * ### Rainfall - mm
# * ### Snowfall - cm
# * ### Seasons - Winter, Spring, Summer, Autumn
# * ### Holiday - Holiday/No holiday
# * ### Functional Day - NoFunc(Non Functional Hours), Fun(Functional hours)

# %% [markdown]
# # **The goal is to turn data into information and information into insight — Carly Fiorina**

# %% [markdown]
# #Importing libraries

# %%
# Importing the  common libraries
import numpy as np
import pandas as pd
from numpy import math
from numpy import loadtxt
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from datetime import datetime     #importing for date time application
import datetime as dt
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import export_graphviz
from graphviz import Source

from IPython.display import SVG
from IPython.display import display


from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.model_selection import RandomizedSearchCV
from sklearn import metrics
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn import ensemble
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
import xgboost as xgb

# %% [markdown]
# # Data Initialization

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/MyDrive/2-CAPSTON PROJECT Bike sharing demand prediction  SUPERWISED ML REGRESSION/Copy of SeoulBikeData.csv'

bike_data = pd.read_csv(file_path, encoding= 'unicode_escape')

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# ### Taking a quick look at our Data

# %%
bike_data.head()
# Out:
#          Date  Rented Bike Count  Hour  ...  Seasons     Holiday  Functioning Day
# 0  01/12/2017                254     0  ...   Winter  No Holiday              Yes
# 1  01/12/2017                204     1  ...   Winter  No Holiday              Yes
# 2  01/12/2017                173     2  ...   Winter  No Holiday              Yes
# 3  01/12/2017                107     3  ...   Winter  No Holiday              Yes
# 4  01/12/2017                 78     4  ...   Winter  No Holiday              Yes
#
# [5 rows x 14 columns]

# %%
# dat description for the info
bike_data.describe(include='all')
# Out:
#               Date  Rented Bike Count  ...     Holiday  Functioning Day
# count         8760        8760.000000  ...        8760             8760
# unique         365                NaN  ...           2                2
# top     13/04/2018                NaN  ...  No Holiday              Yes
# freq            24                NaN  ...        8328             8465
# mean           NaN         704.602055  ...         NaN              NaN
# std            NaN         644.997468  ...         NaN              NaN
# min            NaN           0.000000  ...         NaN              NaN
# 25%            NaN         191.000000  ...         NaN              NaN
# 50%            NaN         504.500000  ...         NaN              NaN
# 75%            NaN        1065.250000  ...         NaN              NaN
# max            NaN        3556.000000  ...         NaN              NaN
#
# [11 rows x 14 columns]

# %% [markdown]
# Looking at Rented bike count, mean is higher than median. So, we got to know there can be outliers.

# %%
#reading no of row and column
bike_data.shape
# Out:
# (8760, 14)

# %% [markdown]
# #Changing column names into simple column names

# %%
# all the column or feature
bike_data.columns
# Out:
# Index(['Date', 'Rented Bike Count', 'Hour', 'Temperature(°C)', 'Humidity(%)',
#        'Wind speed (m/s)', 'Visibility (10m)', 'Dew point temperature(°C)',
#        'Solar Radiation (MJ/m2)', 'Rainfall(mm)', 'Snowfall (cm)', 'Seasons',
#        'Holiday', 'Functioning Day'],
#       dtype='object')

# %%
#rename column
bike_data = bike_data.rename(columns={'Rented Bike Count': 'Rented_Bike_Count', 
                        'Temperature(°C)': 'Temperature',
                        'Humidity(%)': 'Humidity', 
                        'Wind speed (m/s)': 'Wind_speed', 
                        'Visibility (10m)': 'Visibility', 
                        'Dew point temperature(°C)': 'Dew_point_temperature', 
                        'Solar Radiation (MJ/m2)': 'Solar_Radiation', 
                        'Rainfall(mm)': 'Rainfall', 
                        'Snowfall (cm)': 'Snowfall',
                        'Functioning Day': 'Functioning_Day'})

# %% [markdown]
# Simplifying column names for ease of reading.

# %% [markdown]
# #Finding categorical features in our dataset.

# %%
#To find out categorical features in our dataset
bike_data.dtypes
# Out:
# Date                      object
# Rented_Bike_Count          int64
# Hour                       int64
# Temperature              float64
# Humidity                   int64
# Wind_speed               float64
# Visibility                 int64
# Dew_point_temperature    float64
# Solar_Radiation          float64
# Rainfall                 float64
# Snowfall                 float64
# Seasons                   object
# Holiday                   object
# Functioning_Day           object
# dtype: object

# %%
print(bike_data.dtypes.astype(str).value_counts())
# Out:
# float64    6
# object     4
# int64      4
# dtype: int64

# %%
# see all the date or diffrent sesaons and holiday and functioning day
print(bike_data['Seasons'].unique())
print(bike_data['Holiday'].unique())
print(bike_data['Functioning_Day'].unique())
print(bike_data['Date'].unique())
# Out:
# ['Winter' 'Spring' 'Summer' 'Autumn']
# ['No Holiday' 'Holiday']
# ['Yes' 'No']
# ['01/12/2017' '02/12/2017' '03/12/2017' '04/12/2017' '05/12/2017'
#  '06/12/2017' '07/12/2017' '08/12/2017' '09/12/2017' '10/12/2017'
#  '11/12/2017' '12/12/2017' '13/12/2017' '14/12/2017' '15/12/2017'
#  '16/12/2017' '17/12/2017' '18/12/2017' '19/12/2017' '20/12/2017'
#  '21/12/2017' '22/12/2017' '23/12/2017' '24/12/2017' '25/12/2017'
#  '26/12/2017' '27/12/2017' '28/12/2017' '29/12/2017' '30/12/2017'
#  '31/12/2017' '01/01/2018' '02/01/2018' '03/01/2018' '04/01/2018'
#  '05/01/2018' '06/01/2018' '07/01/2018' '08/01/2018' '09/01/2018'
#  '10/01/2018' '11/01/2018' '12/01/2018' '13/01/2018' '14/01/2018'
#  '15/01/2018' '16/01/2018' '17/01/2018' '18/01/2018' '19/01/2018'
#  '20/01/2018' '21/01/2018' '22/01/2018' '23/01/2018' '24/01/2018'
#  '25/01/2018' '26/01/2018' '27/01/2018' '28/01/2018' '29/01/2018'
#  '30/01/2018' '31/01/2018' '01/02/2018' '02/02/2018' '03/02/2018'
#  '04/02/2018' '05/02/2018' '06/02/2018' '07/02/2018' '08/02/2018'
#  '09/02/2018' '10/02/2018' '11/02/2018' '12/02/2018' '13/02/2018'
#  '14/02/2018' '15/02/2018' '16/02/2018' '17/02/2018' '18/02/2018'
#  '19/02/2018' '20/02/2018' '21/02/2018' '22/02/2018' '23/02/2018'
#  '24/02/2018' '25/02/2018' '26/02/2018' '27/02/2018' '28/02/2018'
#  '01/03/2018' '02/03/2018' '03/03/2018' '04/03/2018' '05/03/2018'
#  '06/03/2018' '07/03/2018' '08/03/2018' '09/03/2018' '10/03/2018'
#  '11/03/2018' '12/03/2018' '13/03/2018' '14/03/2018' '15/03/2018'
#  '16/03/2018' '17/03/2018' '18/03/2018' '19/03/2018' '20/03/2018'
#  '21/03/2018' '22/03/2018' '23/03/2018' '24/03/2018' '25/03/2018'
#  '26/03/2018' '27/03/2018' '28/03/2018' '29/03/2018' '30/03/2018'
#  '31/03/2018' '01/04/2018' '02/04/2018' '03/04/2018' '04/04/2018'
#  '05/04/2018' '06/04/2018' '07/04/2018' '08/04/2018' '09/04/2018'
#  '10/04/2018' '11/04/2018' '12/04/2018' '13/04/2018' '14/04/2018'
#  '15/04/2018' '16/04/2018' '17/04/2018' '18/04/2018' '19/04/2018'
#  '20/04/2018' '21/04/2018' '22/04/2018' '23/04/2018' '24/04/2018'
#  '25/04/2018' '26/04/2018' '27/04/2018' '28/04/2018' '29/04/2018'
#  '30/04/2018' '01/05/2018' '02/05/2018' '03/05/2018' '04/05/2018'
#  '05/05/2018' '06/05/2018' '07/05/2018' '08/05/2018' '09/05/2018'
#  '10/05/2018' '11/05/2018' '12/05/2018' '13/05/2018' '14/05/2018'
#  '15/05/2018' '16/05/2018' '17/05/2018' '18/05/2018' '19/05/2018'
#  '20/05/2018' '21/05/2018' '22/05/2018' '23/05/2018' '24/05/2018'
#  '25/05/2018' '26/05/2018' '27/05/2018' '28/05/2018' '29/05/2018'
#  '30/05/2018' '31/05/2018' '01/06/2018' '02/06/2018' '03/06/2018'
#  '04/06/2018' '05/06/2018' '06/06/2018' '07/06/2018' '08/06/2018'
#  '09/06/2018' '10/06/2018' '11/06/2018' '12/06/2018' '13/06/2018'
#  '14/06/2018' '15/06/2018' '16/06/2018' '17/06/2018' '18/06/2018'
#  '19/06/2018' '20/06/2018' '21/06/2018' '22/06/2018' '23/06/2018'
#  '24/06/2018' '25/06/2018' '26/06/2018' '27/06/2018' '28/06/2018'
#  '29/06/2018' '30/06/2018' '01/07/2018' '02/07/2018' '03/07/2018'
#  '04/07/2018' '05/07/2018' '06/07/2018' '07/07/2018' '08/07/2018'
#  '09/07/2018' '10/07/2018' '11/07/2018' '12/07/2018' '13/07/2018'
#  '14/07/2018' '15/07/2018' '16/07/2018' '17/07/2018' '18/07/2018'
#  '19/07/2018' '20/07/2018' '21/07/2018' '22/07/2018' '23/07/2018'
#  '24/07/2018' '25/07/2018' '26/07/2018' '27/07/2018' '28/07/2018'
#  '29/07/2018' '30/07/2018' '31/07/2018' '01/08/2018' '02/08/2018'
#  '03/08/2018' '04/08/2018' '05/08/2018' '06/08/2018' '07/08/2018'
#  '08/08/2018' '09/08/2018' '10/08/2018' '11/08/2018' '12/08/2018'
#  '13/08/2018' '14/08/2018' '15/08/2018' '16/08/2018' '17/08/2018'
#  '18/08/2018' '19/08/2018' '20/08/2018' '21/08/2018' '22/08/2018'
#  '23/08/2018' '24/08/2018' '25/08/2018' '26/08/2018' '27/08/2018'
#  '28/08/2018' '29/08/2018' '30/08/2018' '31/08/2018' '01/09/2018'
#  '02/09/2018' '03/09/2018' '04/09/2018' '05/09/2018' '06/09/2018'
#  '07/09/2018' '08/09/2018' '09/09/2018' '10/09/2018' '11/09/2018'
#  '12/09/2018' '13/09/2018' '14/09/2018' '15/09/2018' '16/09/2018'
#  '17/09/2018' '18/09/2018' '19/09/2018' '20/09/2018' '21/09/2018'
#  '22/09/2018' '23/09/2018' '24/09/2018' '25/09/2018' '26/09/2018'
#  '27/09/2018' '28/09/2018' '29/09/2018' '30/09/2018' '01/10/2018'
#  '02/10/2018' '03/10/2018' '04/10/2018' '05/10/2018' '06/10/2018'
#  '07/10/2018' '08/10/2018' '09/10/2018' '10/10/2018' '11/10/2018'
#  '12/10/2018' '13/10/2018' '14/10/2018' '15/10/2018' '16/10/2018'
#  '17/10/2018' '18/10/2018' '19/10/2018' '20/10/2018' '21/10/2018'
#  '22/10/2018' '23/10/2018' '24/10/2018' '25/10/2018' '26/10/2018'
#  '27/10/2018' '28/10/2018' '29/10/2018' '30/10/2018' '31/10/2018'
#  '01/11/2018' '02/11/2018' '03/11/2018' '04/11/2018' '05/11/2018'
#  '06/11/2018' '07/11/2018' '08/11/2018' '09/11/2018' '10/11/2018'
#  '11/11/2018' '12/11/2018' '13/11/2018' '14/11/2018' '15/11/2018'
#  '16/11/2018' '17/11/2018' '18/11/2018' '19/11/2018' '20/11/2018'
#  '21/11/2018' '22/11/2018' '23/11/2018' '24/11/2018' '25/11/2018'
#  '26/11/2018' '27/11/2018' '28/11/2018' '29/11/2018' '30/11/2018']

# %% [markdown]
# There are 14 columns. 10 are numerical and 4 are categorical columns. 'date' column has multiple information, extracting those informations can be insightful.

# %% [markdown]
# #Checking for null values

# %%
# data information for null value
bike_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Date                   8760 non-null   object
#  1   Rented_Bike_Count      8760 non-null   int64
#  2   Hour                   8760 non-null   int64
#  3   Temperature            8760 non-null   float64
#  4   Humidity               8760 non-null   int64
#  5   Wind_speed             8760 non-null   float64
#  6   Visibility             8760 non-null   int64
#  7   Dew_point_temperature  8760 non-null   float64
#  8   Solar_Radiation        8760 non-null   float64
#  9   Rainfall               8760 non-null   float64
#  10  Snowfall               8760 non-null   float64
#  11  Seasons                8760 non-null   object
#  12  Holiday                8760 non-null   object
#  13  Functioning_Day        8760 non-null   object
# dtypes: float64(6), int64(4), object(4)
# memory usage: 958.2+ KB

# %%
# checkng for no null value
bike_data.isnull().sum()
# Out:
# Date                     0
# Rented_Bike_Count        0
# Hour                     0
# Temperature              0
# Humidity                 0
# Wind_speed               0
# Visibility               0
# Dew_point_temperature    0
# Solar_Radiation          0
# Rainfall                 0
# Snowfall                 0
# Seasons                  0
# Holiday                  0
# Functioning_Day          0
# dtype: int64

# %% [markdown]
# ### Hooray! Dataset has no null

# %% [markdown]
# #Extracting features from date

# %%
#extarcting all usefull from date formate
bike_data['Date']=pd.to_datetime(bike_data['Date'])
bike_data['Year'] = pd.DatetimeIndex(bike_data['Date']).year
bike_data['Day'] = pd.DatetimeIndex(bike_data['Date']).day
bike_data['Month']= pd.DatetimeIndex(bike_data['Date']).month
bike_data['weekday']=pd.DatetimeIndex(bike_data['Date']).weekday

# %%
# data after date time extraction
bike_data.head(2)
# Out:
#         Date  Rented_Bike_Count  Hour  Temperature  ...  Year  Day  Month  weekday
# 0 2017-01-12                254     0         -5.2  ...  2017   12      1        3
# 1 2017-01-12                204     1         -5.5  ...  2017   12      1        3
#
# [2 rows x 18 columns]

# %%
display(bike_data['weekday'].unique())
# Out:
# array([3, 6, 2, 4, 0, 5, 1])

# %%
#weekday is in range 0-6, so we need to make it to normal 1-7
bike_data['weekday'] = np.array(bike_data['weekday'])+1
display(bike_data['weekday'].unique())
# Out:
# array([4, 7, 3, 5, 1, 6, 2])

# %%
# Rented_bike_per_year = pd.DataFrame(df['Rented Bike Count'].groupby(by=df['Year']).sum()).reset_index().sort_values("Year", ascending=True)
# Rented_bike_per_month = pd.DataFrame(df['Rented Bike Count'].groupby(by=df['Month']).sum()).reset_index().sort_values("Month", ascending=True)
# Rented_bike_per_Day= pd.DataFrame(df['Rented Bike Count'].groupby(by=df['Day']).sum()).reset_index().sort_values("Day", ascending=True)
Rented_bike_per_Weekday= pd.DataFrame(bike_data['Rented_Bike_Count'].groupby(by=bike_data['weekday']).sum()).reset_index().sort_values("weekday", ascending=True)
Rented_bike_per_Weekday
# Out:
#    weekday  Rented_Bike_Count
# 0        1             863563
# 1        2             862877
# 2        3             908871
# 3        4             928267
# 4        5             898966
# 5        6             911475
# 6        7             798295

# %%
# read the data for the year
bike_data['Year'].value_counts()
# Out:
# 2018    8016
# 2017     744
# Name: Year, dtype: int64

# %%
# year mont count from the data set
bike_data.groupby(['Year','Month']).agg({'Rented_Bike_Count':['sum']}).reset_index()
# Out:
#     Year Month Rented_Bike_Count
#                              sum
# 0   2017     1              9539
# 1   2017     2              8523
# 2   2017     3              7222
# 3   2017     4              8729
# 4   2017     5              8307
# 5   2017     6              6669
# 6   2017     7              8549
# 7   2017     8              8032
# 8   2017     9              7233
# 9   2017    10              3453
# 10  2017    11              5848
# 11  2017    12            103226
# 12  2018     1            277705
# 13  2018     2            255589
# 14  2018     3            447815
# 15  2018     4            547490
# 16  2018     5            657641
# 17  2018     6            700059
# 18  2018     7            682790
# 19  2018     8            606158
# 20  2018     9            492093
# 21  2018    10            623535
# 22  2018    11            487564
# 23  2018    12            208545

# %%
bike_data['Months_string'] = bike_data['Month'].map({1:'January',2:'February',3:'March',4:'April',5:'May',6:'June',7:'July',8:'August',9:'September',10:'October',11:'November',12:'December'})

# %%
import plotly.express as px

# %%
#line plot for the month_year group
month_year_group= bike_data.groupby(by=['Month','Months_string','Year']).agg({'Rented_Bike_Count':'sum'}).reset_index()
px.line(month_year_group,y= 'Rented_Bike_Count',x= 'Months_string',color= 'Year',title='Total Rented Bikes in 2017 and 2018 on monthly basis',width=1000, height=500)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="bffce9f4-0fcc-40bb-90a0-a8b3ecf61f60" class="plotly-graph-div" style="height:500px; width:1000px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("bffce9f4-0fcc-40bb-90a0-a8b3ecf61f60")) {
#                     Plotly.newPlot(
#                         'bffce9f4-0fcc-40bb-90a0-a8b3ecf61f60',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "Year=2017<br>Months_string=%{x}<br>Rented_Bike_Count=%{y}", "legendgroup": "Year=2017", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "Year=2017", "showlegend": true, "type": "scatter", "x": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], "xaxis": "x", "y": [9539, 8523, 7222, 8729, 8307, 6669, 8549, 8032, 7233, 3453, 5848, 103226], "yaxis": "y"}, {"hoverlabel": {"namelength": 0}, "hovertemplate": "Year=2018<br>Months_string=%{x}<br>Rented_Bike_Count=%{y}", "legendgroup": "Year=2018", "line": {"color": "#EF553B", "dash": "solid"}, "mode": "lines", "name": "Year=2018", "showlegend": true, "type": "scatter", "x": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], "xaxis": "x", "y": [277705, 255589, 447815, 547490, 657641, 700059, 682790, 606158, 492093, 623535, 487564, 208545], "yaxis": "y"}],
#                         {"height": 500, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}] ...

# %%
#bar plot for diffrent year
px.bar(month_year_group,y= 'Rented_Bike_Count',x='Months_string' ,facet_row= 'Year',title='Total Rented Bikes on monthly basis in 2017 and 2018',width=800, height=600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6865c2a6-1257-422d-a462-f47121f5e31e" class="plotly-graph-div" style="height:600px; width:800px;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6865c2a6-1257-422d-a462-f47121f5e31e")) {
#                     Plotly.newPlot(
#                         '6865c2a6-1257-422d-a462-f47121f5e31e',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Year=2017<br>Months_string=%{x}<br>Rented_Bike_Count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], "xaxis": "x2", "y": [9539, 8523, 7222, 8729, 8307, 6669, 8549, 8032, 7233, 3453, 5848, 103226], "yaxis": "y2"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Year=2018<br>Months_string=%{x}<br>Rented_Bike_Count=%{y}", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"], "xaxis": "x", "y": [277705, 255589, 447815, 547490, 657641, 700059, 682790, 606158, 492093, 623535, 487564, 208545], "yaxis": "y"}],
#                         {"annotations": [{"font": {}, "showarrow": false, "text": "Year=2018", "textangle": 90, "x": 0.98, "xanchor": "left", "xref": "paper", "y": 0.2425, "yanchor": "middle", "yref": "paper"}, {"font": {}, "showarrow": false, "text": "Year=2017", "textangle": 90, "x": 0.98, "xanchor": "left", "xref": "paper", "y": 0.7575000000000001, "yanchor": "middle", "yref": "paper"}], "barmode": "relative", "height": 600, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [ ...

# %% [markdown]
# As we can see, Rented bike count was very low in 2017.
#
# In the year 2018, we can see a sharp increase in Rented bike count.
#
# Highest Demand for rented bike is in midyear (may, june, july)

# %% [markdown]
# ### Checking distribution of our dependent variable

# %%
# histogram  plot for the rented bike and year
px.histogram(bike_data, x="Rented_Bike_Count",marginal="violin",color='Year')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f549f6d3-1ed1-4045-a459-ebb30aaaa73f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f549f6d3-1ed1-4045-a459-ebb30aaaa73f")) {
#                     Plotly.newPlot(
#                         'f549f6d3-1ed1-4045-a459-ebb30aaaa73f',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "Year=2017<br>Rented_Bike_Count=%{x}<br>count=%{y}", "legendgroup": "Year=2017", "marker": {"color": "#636efa"}, "name": "Year=2017", "offsetgroup": "Year=2017", "orientation": "v", "showlegend": true, "type": "histogram", "x": [254, 204, 173, 107, 78, 100, 181, 460, 930, 490, 339, 360, 449, 451, 447, 463, 484, 555, 862, 600, 426, 405, 398, 323, 328, 308, 262, 167, 89, 79, 70, 146, 219, 328, 334, 388, 479, 606, 611, 589, 618, 572, 489, 385, 359, 377, 354, 366, 342, 227, 228, 117, 76, 32, 13, 22, 85, 152, 200, 273, 333, 495, 563, 621, 598, 545, 443, 422, 397, 385, 350, 303, 285, 186, 112, 65, 41, 82, 200, 498, 937, 509, 311, 379, 393, 391, 338, 341, 375, 515, 807, 568, 398, 397, 353, 248, 216, 198, 124, 62, 42, 82, 172, 381, 812, 462, 269, 334, 321, 325, 334, 353, 435, 529, 789, 597, 418, 415, 393, 244, 145, 144, 117, 78, 58, 87, 142, 379, 802, 440, 307, 381, 405, 442, 416, 412, 496, 239, 204, 205, 190, 165, 222, 193, 198, 218, 149, 102, 62, 83, 137, 367, 754, 415, 321, 333, 431, 394, 390, 430, 471, 552, 795, 507, 390, 402, 389, 259, 233, 230, 131, 99, 71, 84, 158, 387, 780, 395, 261, 310, 355, 354, 350, 362, 401, 500, 752, 477, 384, 336, 347, 275, 267, 296, 237, 169, 96, 56, 76, 127, 222, 291, 273, 351, 427, 431, 486, 569, 546, 481, 384, 275, 298, 321, 289, 265, 326, 280, 243, 169, 71, 13, 9, 20, 35, 31, 19, 58, 119, 182, 235, 180, 214, 226, 210, 181, 165, 167, 152, 148, 125, 111, 67, 45, 44, 86, 136, 325, 653, 326, 212, 226, 247, 241, 253, 269, 277, 361, 557, 371, 254, 266, 222, 174, 133, 127, 95, 54, 46, 65, 104, 280, 580, 275, 184, 201, 228, 225, 258, 250, 248, 305, 529, 350, 260, 270, 256, 173, 168, 183, 120, 79, 41, 68, 109, 310, 591, 340, 202, 251, 267, 251, 240, 240, 278, 392, 537, 373, 263, 271, 271, 174, 171, 170, 107, 80, 52, 62, 108, 279, 621, 305, 189, 247, 278, 282, 294, 301, 335, 382, 612, 410, 277, 316, 309, 211, 227, 241, 162, 110, 69, 68, 129, 285, 658, 330, 221, 279, 309, 325, 329, 342, 354, 464, 682, 451, 320, 300, 296, 247, 217, 302, 228, 129, 80, 45, 66, 90, 190, 195, 201, 239, 252, 296, 292, 291, 258, 277, 212, 173, 143, 159, 155, 142, 175, 146, 132, 100, 41, 31, 39, 53, 94, 122, 142, 189, 216, 223, 268, 278, 256, 266, 204, 157, 166, 168, 172, 138, 151, 97, 38, 32, 29, 27, 45, 96, 146, 52, 36, 44, 62, 76, 116, 137, 181, 175, 281, 198, 165, 148, 160, 128, 122, 122, 93, 55, 39, 55, 78, 165, 390, 199, 151, 174, 191, 189, 178, 195, 211, 256, 384, 276, 225, 224, 213, 149, 142, 172, 108, 71, 38, 56, 97, 213, 466, 239, 162, 204, 209, 228, 243, 240, 225, 237, 329, 190, 165, 197, 184, 153, 166, 189, 132, 79, 58, 49, 84, 178, 423, 265, 169, 243, 290, 285, 255, 316, 301, 366, 531, 355, 288, 248, 252, 212, 196, 250, 161, 99, 64, 76, 114, 283, 544, 298, 248, 278, 301, 320, 326, 386, 416, 477, 671, 481, 323, 309, 314, 249, 282, 337, 312, 230, 120, 59, 63, 99, 188, 239, 235, 282, 325, 423, 405, 443, 473, 453, 340, 260, 258, 279, 282, 237, 266, 251, 196, 149, 79, 44, 12, 3, 4, 3, 4, 9, 4, 7, 28, 38, 54, 104, 128, 132, 116, 145, 110, 128, 160, 132, 115, 100, 72, 32, 59, 61, 94, 107, 133, 179, 221, 244, 274, 319, 272, 260, 237, 184, 181, 185, 176, 169, 178, 127, 85, 72, 49, 65, 120, 296, 578, 293, 180, 250, 262, 262, 271, 246, 282, 350, 481, 317, 252, 220, 213, 156, 133, 142, 93, 81, 55, 66, 105, 262, 502, 279, 146, 213, 230, 258, 231, 228, 269, 314, 466, 315, 262, 242, 243, 216, 164, 169, 163, 86, 50, 61, 103, 257, 554, 326, 225, 288, 286, 301, 311, 303, 390, 407, 552, 402, 319, 332, 285, 260, 233, 269, 210, 135, 85, 67, 128, 289, 636, 353, 252, 317, 363, 370, 419, 426, 504, 534, 574, 395, 292, 282, 294, 236, 240, 234, 192, 127, 86, 52, 62, 88, 162, 224, 208, 237, 274, 333, 356, 337, 345, 183, 45, 40, 66, 64, 30, 42, 43, 43, 65, 65, 32, 22, 25, 39, 84, 103, 110, 142, 209, 267, 262, 300, 272, 240, 215, 163, 161, 179, 155, 227], "xaxis": "x", "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelen ...

# %%
sns.boxplot(x = bike_data['Rented_Bike_Count'])

# %%
#square root transformation
px.histogram(bike_data, x=np.sqrt(bike_data["Rented_Bike_Count"]),color='Year',marginal="violin", title='Probalility density of Square root transformation of Number of Rented Bikes',histnorm='probability density')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1e7fdd13-bc82-4594-ba16-6098a8e7d96d" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1e7fdd13-bc82-4594-ba16-6098a8e7d96d")) {
#                     Plotly.newPlot(
#                         '1e7fdd13-bc82-4594-ba16-6098a8e7d96d',
#                         [{"alignmentgroup": "True", "bingroup": "x", "histnorm": "probability density", "hoverlabel": {"namelength": 0}, "hovertemplate": "Year=2017<br>x=%{x}<br>count=%{y}", "legendgroup": "Year=2017", "marker": {"color": "#636efa"}, "name": "Year=2017", "offsetgroup": "Year=2017", "orientation": "v", "showlegend": true, "type": "histogram", "x": [15.937377450509228, 14.2828568570857, 13.152946437965905, 10.344080432788601, 8.831760866327848, 10.0, 13.45362404707371, 21.447610589527216, 30.495901363953813, 22.135943621178654, 18.411952639521967, 18.973665961010276, 21.18962010041709, 21.236760581595302, 21.142374511865974, 21.517434791350013, 22.0, 23.558437978779494, 29.359836511806396, 24.49489742783178, 20.639767440550294, 20.12461179749811, 19.949937343260004, 17.97220075561143, 18.110770276274835, 17.549928774784245, 16.186414056238647, 12.922847983320086, 9.433981132056603, 8.888194417315589, 8.366600265340756, 12.083045973594572, 14.798648586948742, 18.110770276274835, 18.275666882497067, 19.697715603592208, 21.88606862823929, 24.61706725018234, 24.71841418861655, 24.269322199023193, 24.859605789312106, 23.916521486202797, 22.11334438749598, 19.621416870348583, 18.947295321496416, 19.4164878389476, 18.81488772222678, 19.131126469708992, 18.49324200890693, 15.066519173319364, 15.0996688705415, 10.816653826391969, 8.717797887081348, 5.656854249492381, 3.605551275463989, 4.69041575982343, 9.219544457292887, 12.328828005937952, 14.142135623730951, 16.522711641858304, 18.24828759089466, 22.24859546128699, 23.727621035409346, 24.919871588754223, 24.454038521274967, 23.345235059857504, 21.047565179849187, 20.54263858417414, 19.924858845171276, 19.621416870348583, 18.708286933869708, 17.406895185529212, 16.881943016134134, 13.638181696985855, 10.583005244258363, 8.06225774829855, 6.4031242374328485, 9.055385138137417, 14.142135623730951, 22.315913604421397, 30.610455730027933, 22.561028345356956, 17.635192088548397, 19.467922333931785, 19.82422760159901, 19.77371993328519, 18.384776310850235, 18.466185312619388, 19.364916731037084, 22.693611435820433, 28.407745422683583, 23.83275057562597, 19.949937343260004, 19.924858845171276, 18.788294228055936, 15.748015748023622, 14.696938456699069, 14.071247279470288, 11.135528725660043, 7.874007874011811, 6.48074069840786, 9.055385138137417, 13.114877048604, 19.519221295943137, 28.495613697550013, 21.494185260204677, 16.401219466856727, 18.275666882497067, 17.916472867168917, 18.027756377319946, 18.275666882497067, 18.788294228055936, 20.85665361461421, 23.0, 28.089143810376278, 24.43358344574123, 20.445048300260872, 20.37154878746336, 19.82422760159901, 15.620499351813308, 12.041594578792296, 12.0, 10.816653826391969, 8.831760866327848, 7.615773105863909, 9.327379053088816, 11.916375287812984, 19.467922333931785, 28.319604517012593, 20.97617696340303, 17.52141546793523, 19.519221295943137, 20.12461179749811, 21.02379604162864, 20.396078054371138, 20.29778313018444, 22.271057451320086, 15.459624833740307, 14.2828568570857, 14.317821063276353, 13.784048752090222, 12.84523257866513, 14.89966442575134, 13.892443989449804, 14.071247279470288, 14.7648230602334, 12.206555615733702, 10.099504938362077, 7.874007874011811, 9.1104335791443, 11.704699910719626, 19.157244060668017, 27.459060435491963, 20.37154878746336, 17.916472867168917, 18.24828759089466, 20.760539492026695, 19.849433241279208, 19.748417658131498, 20.73644135332772, 21.702534414210707, 23.49468024894146, 28.19574435974337, 22.516660498395403, 19.748417658131498, 20.049937655763422, 19.72308292331602, 16.09347693943108, 15.264337522473747, 15.165750888103101, 11.445523142259598, 9.9498743710662, 8.426149773176359, 9.16515138991168, 12.569805089976535, 19.672315572906, 27.92848008753788, 19.87460691435179, 16.15549442140351, 17.60681686165901, 18.841443681416774, 18.81488772222678, 18.708286933869708, 19.026297590440446, 20.024984394500787, 22.360679774997898, 27.422618401604176, 21.840329667841555, 19.595917942265 ...

# %%
sns.boxplot(x = np.sqrt(bike_data["Rented_Bike_Count"]))

# %% [markdown]
# ### Our Model works best when we have normal distribution. Normal distribution for model building as it makes math easier. Models like LDA, Gaussian Naive Bayes, Logistic Regression, Linear Regression, etc., are explicitly calculated from the assumption that the distribution is a bivariate or multivariate normal.

# %% [markdown]
# #Exploring Categorical variables

# %%
bike_data.columns
# Out:
# Index(['Date', 'Rented_Bike_Count', 'Hour', 'Temperature', 'Humidity',
#        'Wind_speed', 'Visibility', 'Dew_point_temperature', 'Solar_Radiation',
#        'Rainfall', 'Snowfall', 'Seasons', 'Holiday', 'Functioning_Day', 'Year',
#        'Day', 'Month', 'weekday', 'Months_string'],
#       dtype='object')

# %% [markdown]
# **Counting no. of sections in categorical features in dataset**

# %%
#count plot for diffrent seasons
sns.countplot(x ='Seasons', data = bike_data)

# %% [markdown]
# In our dataset, information about all months are given.

# %%
#comment for countplot for year
sns.countplot(x ='Year', data = bike_data)

# %% [markdown]
# Our dataset mostly contains information of year 2018 and very little information of year 2017.

# %% [markdown]
# **Finding relation between variables USING BAR PLOT**

# %%
#Finding relation betwwen seasons and rented bike count. telling us rented bike count on that season.
# sns.set_style('darkgrid')
sns.barplot(x ='Seasons', y ='Rented_Bike_Count', data = bike_data, palette ='tab10')

# %% [markdown]
# Rented bike count is less in winter and almost consistantly higher in other months.

# %%
#plot for the rented bike forweekday
sns.barplot(x ='weekday', y ='Rented_Bike_Count', data = bike_data, palette ='tab10')

# %% [markdown]
# In all days, rented bike count is consistant and equal.

# %%
#holiday or not holiday plot
sns.countplot(x ='Functioning_Day',hue = 'Holiday', data = bike_data)

# %% [markdown]
# ### We got to know all Holidays are falling into functioning days.

# %% [markdown]
# # **The world is now awash with Data and we can see consumers in a lot clearer.**

# %% [markdown]
# #Exploring Numerical Variables

# %%
bike_data.columns
# Out:
# Index(['Date', 'Rented_Bike_Count', 'Hour', 'Temperature', 'Humidity',
#        'Wind_speed', 'Visibility', 'Dew_point_temperature', 'Solar_Radiation',
#        'Rainfall', 'Snowfall', 'Seasons', 'Holiday', 'Functioning_Day', 'Year',
#        'Day', 'Month', 'weekday', 'Months_string'],
#       dtype='object')

# %%
#selecting numerical features
numerical_features = ['Hour', 'Temperature', 'Humidity',
       'Wind_speed', 'Visibility', 'Dew_point_temperature', 'Solar_Radiation',
       'Rainfall', 'Snowfall' ]

# %%
# List of colors in the color palettes
rgb_values = sns.color_palette("bright")

# %%
# Map continents to the colors
color_map = dict(zip(numerical_features, rgb_values))

# %%
#plot for numerical feature
plt.rcParams['figure.figsize'] = (8, 6)
for col, key in zip(numerical_features, color_map):
  plt.figure()
  sns.regplot(x=bike_data[col], y = bike_data['Rented_Bike_Count'],scatter_kws={"color": color_map[key]}, line_kws={"color": "Red"})

# %% [markdown]
# ### **Effects of Numerical features in rented bike count:-**
#
# * **Hour:** Demand for bike is mostly in morning (7 to 8) and in the evening (3 to 9).
#
# * **Temperature :** Temperature is positively correlated. Rented bike count is highest between 20 °C and 30 °C. So, it means temperature has an effect.
#
# * **Humidity :**
# Humidity is the amount of water vapor in the air. So, People preferring to borrow bike When there is less humidity.
#
# * **Wind_speed :**
# wind speed doesn't affect our data much.
#
# * **Visibility:**
# Visibility doesn't affect our results much but all we know is that it is positively correlated with bike count.
#
# * **SnowFall and Rainfall:**
# People don't prefer borrowing bike, where there is rainfall or snowfall.
#
# * **Dew point:**
# The dew point is the temperature the air needs to be cooled to (at constant pressure) in order to achieve a relative humidity. It is positively correlated with data.

# %%
sns.set(font_scale=1.0)
fig, axes = plt.subplots(nrows=4,ncols=2)
fig.set_size_inches(15, 15)

sns.boxplot(data=bike_data,y="Rented_Bike_Count",x="Humidity",orient="v",ax=axes[0][0])
sns.boxplot(data=bike_data,y="Rented_Bike_Count",x="Hour",orient="v",ax=axes[0][0])
sns.boxplot(data=bike_data,y="Rented_Bike_Count",x="Temperature",orient="v",ax=axes[1][0])
sns.boxplot(data=bike_data,y="Rented_Bike_Count",x="Wind_speed",orient="v",ax=axes[1][1])
sns.boxplot(data=bike_data,y="Rented_Bike_Count",x="Visibility",orient="v",ax=axes[2][0])
sns.boxplot(data=bike_data,y="Rented_Bike_Count",x="Seasons",orient="v",ax=axes[2][1])
sns.boxplot(data=bike_data,y="Rented_Bike_Count",x="Holiday",orient="v",ax=axes[3][0])
sns.boxplot(data=bike_data,y="Rented_Bike_Count",x="Solar_Radiation",orient="v",ax=axes[3][1])

# %% [markdown]
# ### Finding Correlation of Dependent variable with other variables

# %%
# bar plot between hr and rented bike count
plt.figure(figsize=(10,8))
sns.lineplot(x = bike_data['Hour'],y = bike_data['Rented_Bike_Count'])
sns.barplot(x = bike_data['Hour'],y = bike_data['Rented_Bike_Count'], color="salmon")

# %%
# group by Hrs and get average Bikes rented, and precent change
avg_rent_hrs = bike_data.groupby('Hour')['Rented_Bike_Count'].mean()
pct_rent_hrs = bike_data.groupby('Hour')['Rented_Bike_Count'].sum().pct_change()

fig, (axis1,axis2) = plt.subplots(2,1,sharex=True,figsize=(15,8))

# plot average rent over time(hrs)
ax1 = avg_rent_hrs.plot(legend=True,ax=axis1,marker='o',title="Average Bikes Rented Per Hr")
ax1.set_xticks(range(len(avg_rent_hrs)))
ax1.set_xticklabels(avg_rent_hrs.index.tolist(), rotation=85)

# plot precent change for rent over time(hrs)
ax2 = pct_rent_hrs.plot(legend=True,ax=axis2,marker='o',rot=85,colormap="summer",title="Bike Rent Percent Change")
#ax1.set_xticks(range(len(avg_rent_hrs)))

# %% [markdown]
# Consumers are renting bikes more in specific hours of a day. In morning it is 7:00 to 9:00 and then in evening from 15:00 to 19:00.

# %%
# line plot seasonal varaition
plt.figure(figsize=(12,4), dpi=100)
sns.lineplot(data=bike_data, x="Hour", y="Rented_Bike_Count", hue="Seasons")

# %% [markdown]
# There is an Amazing insight that consumers prefer borrowing bikes more in a particular season. Rented bike count is highest in summer and least in winter.

# %% [markdown]
# ### **Relational Analysis - Find correlation between different variables**

# %%
#correlation data
np.round(bike_data.corr()['Rented_Bike_Count'],3)
# Out:
# Rented_Bike_Count        1.000
# Hour                     0.410
# Temperature              0.539
# Humidity                -0.200
# Wind_speed               0.121
# Visibility               0.199
# Dew_point_temperature    0.380
# Solar_Radiation          0.262
# Rainfall                -0.123
# Snowfall                -0.142
# Year                     0.215
# Day                      0.047
# Month                    0.071
# weekday                 -0.022
# Name: Rented_Bike_Count, dtype: float64

# %% [markdown]
# Hour and temperature are highly correlated with bike count.

# %% [markdown]
# **let's drop some columns which are not important**

# %%
# dropping the non-perfoming column
bike_data.drop('Months_string',axis=1,inplace=True)
bike_data.drop('Date',axis=1,inplace=True)

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = bike_data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(14,11))
#plot heat map
g=sns.heatmap(bike_data[top_corr_features].corr(),annot=True,cmap="RdYlGn",center=0.3)

# %% [markdown]
# Temperature and Dew point temperature are highly correlated. We can add them to make one single column

# %%
# creating new  features
bike_data['Temperature_and_DP_Temp'] = [bike_data['Temperature'][i]+bike_data['Dew_point_temperature'][i] for i in range(len(bike_data))]
bike_data.drop(['Temperature','Dew_point_temperature'],axis=1,inplace=True)

# %%
#correlation plot
corrmat = bike_data.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(14,11))
#plot heat map
g=sns.heatmap(bike_data[top_corr_features].corr(),annot=True,cmap="RdYlGn",center=0.3)

# %% [markdown]
# # **Data are just summaries of thousand of stories.**

# %%
#creating dummies column for the given feature
bike_data=pd.get_dummies(bike_data,drop_first=True)

# %%
# table after feature engineering
bike_data.head()
# Out:
#    Rented_Bike_Count  Hour  ...  Holiday_No Holiday  Functioning_Day_Yes
# 0                254     0  ...                   1                    1
# 1                204     1  ...                   1                    1
# 2                173     2  ...                   1                    1
# 3                107     3  ...                   1                    1
# 4                 78     4  ...                   1                    1
#
# [5 rows x 18 columns]

# %%
# removing less importance column
bike_data.drop('weekday',axis=1,inplace=True)

# %%
bike_data.head()
# Out:
#    Rented_Bike_Count  Hour  ...  Holiday_No Holiday  Functioning_Day_Yes
# 0                254     0  ...                   1                    1
# 1                204     1  ...                   1                    1
# 2                173     2  ...                   1                    1
# 3                107     3  ...                   1                    1
# 4                 78     4  ...                   1                    1
#
# [5 rows x 17 columns]

# %%
# shape of the data
bike_data.shape
# Out:
# (8760, 17)

# %% [markdown]
# Our Dataset is ready.

# %% [markdown]
# # **Model Building**

# %%
# Data for all the independent variables
X = bike_data.drop(labels='Rented_Bike_Count',axis=1)

# Data for the dependent variable

y = np.sqrt(bike_data['Rented_Bike_Count'])
y.head()
# Out:
# 0    15.937377
# 1    14.282857
# 2    13.152946
# 3    10.344080
# 4     8.831761
# Name: Rented_Bike_Count, dtype: float64

# %%
# Feature Importance

from sklearn.ensemble import ExtraTreesRegressor
import matplotlib.pyplot as plt
model = ExtraTreesRegressor()
model.fit(X,y)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
print(model.feature_importances_)
# Out:
# [0.26077071 0.11738389 0.0136922  0.02990137 0.0648807  0.03373743
#  0.0027179  0.00132725 0.01880122 0.01668054 0.06555445 0.01709663
#  0.00998727 0.18194059 0.00546975 0.16005809]

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %% [markdown]
# #Train Test Split  for Model

# %%
#import train-test split lib
from sklearn.model_selection import train_test_split

# %%
# function which split data into train and test
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=34)

# %%
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (7008, 16) (7008,)
# (1752, 16) (1752,)

# %% [markdown]
# ## **In this project we are using seven model on our data set for getting best performance:-**
#
# LINEAR REGRESSION
#
# LASSO REGRESSION
#
# RIDGE REGRESSION
#
# ELASTICNET REGRESSION
#
# GRADIENT BOOSTING
#
# DECISION TREE
#
# RANDOM FORREST
#
# XGBOOST

# %% [markdown]
# #Linear Regression Model
# linear regression have some assumptions, given below are the basic assumptions that a linear regression model makes regarding a dataset on which it is applied:
#
# * **Linear relationship**: Relationship between response and feature variables should be linear. The linearity assumption can be tested using scatter plots.
# * **Little or no multi-collinearity**: It is assumed that there is little or no multicollinearity in the data. Multicollinearity occurs when the features (or independent variables) are not independent from each other.
# * **Little or no auto-correlation**: Another assumption is that there is little or no autocorrelation in the data. Autocorrelation occurs when the residual errors are not independent from each other.
# * **Homoscedasticity**: Homoscedasticity describes a situation in which the error term (that is, the “noise” or random disturbance in the relationship between the independent variables and the dependent variable) is the same across all values of the independent

# %%
#importing linear regression model
from sklearn.linear_model import LinearRegression
reg= LinearRegression().fit(X_train, y_train)

# %%
# all coeffient
reg.score(X_train, y_train)
# Out:
# 0.6547192361864398

# %%
#diffresnt coefficient for different features
reg.coef_
# Out:
# array([ 4.87925477e-01, -2.29940503e-01,  1.89672962e-01, -1.56414191e-04,
#        -8.02486527e-01, -1.39558289e+00,  1.86527269e-01, -2.64795650e+00,
#        -1.86084876e-02, -2.30326900e-02,  2.47906155e-01, -2.89868003e+00,
#        -2.84332142e+00, -9.04145095e+00,  2.85999149e+00,  2.84894893e+01])

# %%
# pred train test
y_pred_train=reg.predict(X_train)
y_pred_test=reg.predict(X_test)

# %%
#metrics for linear regession analysis
from sklearn.metrics import mean_squared_error
MSE= mean_squared_error((y_train), (y_pred_train))
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)




from sklearn.metrics import r2_score
r2= r2_score(y_train, y_pred_train)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_train, y_pred_train))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# MSE : 52.95555328513579
# RMSE : 7.277056636108846
# R2 : 0.6547192361864398
# Adjusted R2 : 0.6515350908140958

# %%
#metrics for linear regression analysis for test dataset
from sklearn.metrics import mean_squared_error
MSE= mean_squared_error((y_test), (y_pred_test))
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)
r2= r2_score(y_test, y_pred_test)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_test, y_pred_test))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# MSE : 55.08739505098533
# RMSE : 7.4220883214217634
# R2 : 0.6588467149667641
# Adjusted R2 : 0.6557006327993107

# %%
#predicted vs actual for test data
plt.figure(figsize=(10,5))
plt.plot(np.array(y_pred_test))
plt.plot(np.array((y_test)))
plt.legend(["Predicted","Actual"])
plt.show()

# %%
# Heteroscedasticity
plt.scatter((y_pred_test),(y_test)-(y_pred_test))

# %% [markdown]
# ## **In the end, you should only measure and look at the numbers that drive action, meaning that the data tells you what you should do next. - ALEX PEINIGEER**

# %% [markdown]
# # Implementing lasso Regression

# %%
#importing lasso regression model
from sklearn.linear_model import Lasso
lasso=Lasso(alpha=0.1,max_iter=3000)
lasso.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=3000,
#       normalize=False, positive=False, precompute=False, random_state=None,
#       selection='cyclic', tol=0.0001, warm_start=False)

# %%
# lasso score 
lasso.score(X_train, y_train)
# Out:
# 0.6436819185266032

# %%
# lasso y pred test and train
y_pred_train_lasso=lasso.predict(X_train)
y_pred_test_lasso=lasso.predict(X_test)

# %%
# metrics for lasso regressor flor train dataset
from sklearn.metrics import mean_squared_error
MSE= mean_squared_error((y_train), (y_pred_train_lasso))
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)
from sklearn.metrics import r2_score
r2= r2_score(y_train, y_pred_train_lasso)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_train, y_pred_train_lasso))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# MSE : 54.64834166119503
# RMSE : 7.392451667829492
# R2 : 0.6436819185266032
# Adjusted R2 : 0.6403959880922664

# %%
# mterics for lasso regressor flor test dataset
from sklearn.metrics import mean_squared_error
MSE= mean_squared_error((y_test), (y_pred_test_lasso))
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)
from sklearn.metrics import r2_score
r2= r2_score(y_test, y_pred_test_lasso)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_test, y_pred_test_lasso))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# MSE : 57.49564641514416
# RMSE : 7.582588371733241
# R2 : 0.643932543343507
# Adjusted R2 : 0.6406489241466748

# %%
plt.figure(figsize=(8,5))
plt.plot(np.array(y_pred_test_lasso))
plt.plot(np.array((y_test)))
plt.legend(["Predicted","Actual"])
plt.show()

# %%
# Heteroscedasticity
plt.scatter((y_pred_test_lasso),(y_test-y_pred_test_lasso))

# %% [markdown]
# # Implementing Ridge Regression

# %%
#importing ridge regression
from sklearn.linear_model import Ridge

ridge= Ridge(alpha=0.1)
ridge.fit(X_train,y_train)
# Out:
# Ridge(alpha=0.1, copy_X=True, fit_intercept=True, max_iter=None,
#       normalize=False, random_state=None, solver='auto', tol=0.001)

# %%
# ridge score
ridge.score(X_train, y_train)
# Out:
# 0.6547191910419368

# %%
#y pred  ridge test and train
y_pred_train_ridge=ridge.predict(X_train)
y_pred_test_ridge=ridge.predict(X_test)

# %%
# metrics for ridge regression
from sklearn.metrics import mean_squared_error
MSE= mean_squared_error((y_train), (y_pred_train_ridge))
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)


from sklearn.metrics import r2_score
r2= r2_score(y_train, y_pred_train_ridge)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_train, y_pred_train_ridge))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# MSE : 52.955560208927636
# RMSE : 7.277057111836325
# R2 : 0.6547191910419368
# Adjusted R2 : 0.6515350452532745

# %%
# metrics for ridge regression for test
from sklearn.metrics import mean_squared_error
MSE= mean_squared_error((y_test), (y_pred_test_ridge))
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)


from sklearn.metrics import r2_score
r2= r2_score(y_test, y_pred_test_ridge)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_test, y_pred_test_ridge))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# MSE : 55.08773606712857
# RMSE : 7.422111294445036
# R2 : 0.6588446030720665
# Adjusted R2 : 0.655698501428927

# %%
#plot for ridge 
plt.figure(figsize=(8,5))
plt.plot((y_pred_test_ridge))
plt.plot((np.array(y_test)))
plt.legend(["Predicted","Actual"])
plt.show()

# %%
# Heteroscedasticity
plt.scatter((y_pred_test_ridge),(y_test)-(y_pred_test_ridge))

# %% [markdown]
# # Implementing Elastic Net Regressor

# %%
#importing elasticNet model
from sklearn.linear_model import ElasticNet
elasticnet = ElasticNet(alpha=0.1, l1_ratio=0.5)
#a*l1+b*l2
#alpha=a+b and l1 ratio=a/a+b
elasticnet.fit(X_train,y_train)
# Out:
# ElasticNet(alpha=0.1, copy_X=True, fit_intercept=True, l1_ratio=0.5,
#            max_iter=1000, normalize=False, positive=False, precompute=False,
#            random_state=None, selection='cyclic', tol=0.0001, warm_start=False)

# %%
#elastic net score

elasticnet.score(X_train, y_train)
# Out:
# 0.5801724303474118

# %%
#y_predict for train and test dataset
y_pred_train_en=elasticnet.predict(X_train)
y_pred_test_en=elasticnet.predict(X_test)

# %%
#metrics for the elasticnet regression on train
from sklearn.metrics import mean_squared_error
MSE= mean_squared_error((y_train), (y_pred_train_en))
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)


from sklearn.metrics import r2_score
r2= r2_score(y_train, y_pred_train_en)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_train, y_pred_train_en))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# MSE : 64.38876290053423
# RMSE : 8.024260894346234
# R2 : 0.5801724303474118
# Adjusted R2 : 0.5763008216359182

# %%
#metrics for the elasticnet regression on test
from sklearn.metrics import mean_squared_error
MSE= mean_squared_error((y_test), (y_pred_test_en))
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)

from sklearn.metrics import r2_score
r2= r2_score(y_test, y_pred_test_en)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_test, y_pred_test_en))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# MSE : 67.17969621593292
# RMSE : 8.196322115188796
# R2 : 0.5839597419629589
# Adjusted R2 : 0.5801230594680928

# %%
#plot for pred vs actual for test
plt.figure(figsize=(8,5))
plt.plot(np.array(y_pred_test_en))
plt.plot((np.array(y_test)))
plt.legend(["Predicted","Actual"])
plt.show()

# %%
#Heteroscedasticity
plt.scatter((y_pred_test_en),(y_test)-(y_pred_test_en))

# %% [markdown]
# # Implementing of decision tree by using decision tree regressor

# %%
#importing the decision tree model for training 
decision_regressor = DecisionTreeRegressor(criterion='mse', max_depth=8,
                      max_features=9, max_leaf_nodes=100,)
decision_regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=8,
#                       max_features=9, max_leaf_nodes=100,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=None, splitter='best')

# %%
#y pred for test and train data
y_pred_train_dt = decision_regressor.predict(X_train)
y_pred_test_dt = decision_regressor.predict(X_test)

# %%
#metric for decison tree for train data
from sklearn.metrics import mean_squared_error
print("Model Score:",decision_regressor.score(X_train,y_train))

MSE= mean_squared_error(y_train, y_pred_train_dt)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)

from sklearn.metrics import r2_score
r2= r2_score(y_train, y_pred_train_dt)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_train, y_pred_train_dt))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# Model Score: 0.8347132584343252
# MSE : 25.349952176987767
# RMSE : 5.03487360089484
# R2 : 0.8347132584343252
# Adjusted R2 : 0.8331890002988492

# %%
#metric for decison tree for test data
from sklearn.metrics import mean_squared_error
MSE= mean_squared_error(y_test, y_pred_test_dt)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)

from sklearn.metrics import r2_score
r2= r2_score((y_test), (y_pred_test_dt))
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score((y_test), (y_pred_test_dt)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# MSE : 29.017374714885666
# RMSE : 5.386777767356443
# R2 : 0.8202969536341048
# Adjusted R2 : 0.8186397497483098

# %%
#pred vs actual for decision tree
plt.figure(figsize=(8,5))
plt.plot((np.array(y_pred_test_dt)))
plt.plot(np.array((y_test)))
plt.legend(["Predicted","Actual"])
plt.show()

# %%
# Heteroscedasticity
plt.scatter((y_pred_test_dt),(y_test)-(y_pred_test_dt))

# %% [markdown]
# # Visualization of decision tree

# %%
# decision tree visualization
graph = Source(tree.export_graphviz(decision_regressor, out_file=None
   , feature_names=X_train.columns, class_names=['0', '1'] 
   , filled = True))
display(SVG(graph.pipe(format='svg')))

# %% [markdown]
# # Implementing Random forest Rergressor

# %%
#creating an instance for the random forest
rf_model=RandomForestRegressor()
rf_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
# Making predictions on train and test data in rf

y_pred_train_rf = rf_model.predict(X_train)
y_pred_test_rf = rf_model.predict(X_test)

# %%
#metric score for the rf for train dataset
from sklearn.metrics import mean_squared_error
print("Model Score:",rf_model.score(X_train,y_train))

MSE= mean_squared_error(y_train, y_pred_train_rf)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)
from sklearn.metrics import r2_score
r2= r2_score(y_train, y_pred_train_rf)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_train, y_pred_train_rf))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# Model Score: 0.9869685510762397
# MSE : 1.9986273786087179
# RMSE : 1.413728184131843
# R2 : 0.9869685510762397
# Adjusted R2 : 0.9868483763311214

# %%
#metric score for the rf for test dataset
print("Model Score:",rf_model.score(X_test,y_test))

MSE= mean_squared_error(y_test, y_pred_test_rf)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)
from sklearn.metrics import r2_score
r2= r2_score(y_test, y_pred_test_rf)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_test, y_pred_test_rf))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# Model Score: 0.9096186697734514
# MSE : 14.594237434760124
# RMSE : 3.8202404943615953
# R2 : 0.9096186697734514
# Adjusted R2 : 0.9087851820019097

# %%
#pred vs actual for random forest
plt.figure(figsize=(8,5))
plt.plot((np.array(y_pred_test_rf)))
plt.plot(np.array((y_test)))
plt.legend(["Predicted","Actual"])
plt.show()

# %%
#Heteroscedasticity
plt.scatter((y_pred_test_rf),(y_test)-(y_pred_test_rf))

# %%
# random forest important feature selection
rf_model.feature_importances_
# Out:
# array([0.28672651, 0.14357012, 0.01278109, 0.01470712, 0.02395599,
#        0.03126389, 0.00158026, 0.00111783, 0.01772526, 0.01135405,
#        0.0994112 , 0.00589226, 0.00399736, 0.17874966, 0.00223471,
#        0.16493272])

# %%
importance_rf=rf_model.feature_importances_

# %%
imortance_rf_dict={"Feature":list(X_train.columns),"Feature importance":importance_rf}
imortance_rf_df=pd.DataFrame(imortance_rf_dict)

# %%
imortance_rf_df["Feature importance"]=round(imortance_rf_df["Feature importance"],2)

# %%
imortance_rf_df.sort_values(by=["Feature importance"],ascending=False)
# Out:
#                     Feature  Feature importance
# 0                      Hour                0.29
# 13           Seasons_Winter                0.18
# 15      Functioning_Day_Yes                0.16
# 1                  Humidity                0.14
# 10  Temperature_and_DP_Temp                0.10
# 5                  Rainfall                0.03
# 4           Solar_Radiation                0.02
# 8                       Day                0.02
# 2                Wind_speed                0.01
# 3                Visibility                0.01
# 9                     Month                0.01
# 11           Seasons_Spring                0.01
# 6                  Snowfall                0.00
# 7                      Year                0.00
# 12           Seasons_Summer                0.00
# 14       Holiday_No Holiday                0.00

# %%
rf_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
features=X_train.columns
importance_rf=rf_model.feature_importances_
indices=np.argsort(importance_rf)

# %%
plt.title("feature importance")
plt.barh(range(len(indices)),importance_rf[indices],color="green",align="center")

plt.yticks(range(len(indices)),[features[i] for i in indices])
plt.xlabel("Relative importance") 
plt.show()

# %% [markdown]
# # Training Random forest Regressor from GridesearchCV

# %%
# number of trees
n_estimators=[50,80,100]

#max deapth of tree
max_depth=[4,6,8]

#minimum no of sample required for spliting the node
min_samples_split=[50,100,150]

#minimum no of sample required at each leaf node
min_samples_leaf=[40,50]
#hyper parametr gride
param_dict = {'n_estimators' : n_estimators,
              'max_depth' : max_depth,
              'min_samples_split' : min_samples_split,
              'min_samples_leaf' : min_samples_leaf}

# %%
param_dict
# Out:
# {'max_depth': [4, 6, 8],
#  'min_samples_leaf': [40, 50],
#  'min_samples_split': [50, 100, 150],
#  'n_estimators': [50, 80, 100]}

# %% [markdown]
# # Importing Random forest Regressor

# %%
# Create an instance of the RandomForestRegressor
rf_model = RandomForestRegressor()

# Grid search
rf_grid = GridSearchCV(estimator=rf_model,
                       param_grid = param_dict,
                       cv = 5, verbose=2)

rf_grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.5s remaining:    0.0s
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.8s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.8s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.8s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.8s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.8s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.8s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.8s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   0.8s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   0.8s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   0.8s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.7s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   0.8s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   0.8s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.2s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.2s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.2s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.2s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.5s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.4s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.4s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.7s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.2s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.3s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.3s
# [Parallel(n_jobs=1)]: Done 270 out of 270 | elapsed:  3.8min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [4, 6, 8], 'min_samples_leaf': [40, 50],
#                          'min_samples_split': [50, 100, 150],
#                          'n_estimators': [50, 80, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
rf_grid.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=8, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=40,
#                       min_samples_split=50, min_weight_fraction_leaf=0.0,
#                       n_estimators=80, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_optimal_model = rf_grid.best_estimator_

# %%
rf_grid.best_params_
# Out:
# {'max_depth': 8,
#  'min_samples_leaf': 40,
#  'min_samples_split': 50,
#  'n_estimators': 80}

# %%
# Making predictions on train and test data

y_pred_train_r_g = rf_optimal_model.predict(X_train)
y_pred_test_r_g = rf_optimal_model.predict(X_test)

# %%
#metrics for rf score with gd for train
from sklearn.metrics import mean_squared_error
print("Model Score:",rf_optimal_model.score(X_train,y_train))

MSE= mean_squared_error(y_train, y_pred_train_r_g)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)


from sklearn.metrics import r2_score
r2= r2_score(y_train, y_pred_train_r_g)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_train, y_pred_train_r_g))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# Model Score: 0.8447042164396448
# MSE : 23.81764350396266
# RMSE : 4.880332314910805
# R2 : 0.8447042164396448
# Adjusted R2 : 0.8432720939399527

# %%
#metrics for rf score with gd for test
from sklearn.metrics import mean_squared_error
print("Model Score:",rf_optimal_model.score(X_train,y_train))

MSE= mean_squared_error(y_test, y_pred_test_r_g)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)


from sklearn.metrics import r2_score
r2= r2_score(y_test, y_pred_test_r_g)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_test, y_pred_test_r_g))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# Model Score: 0.8447042164396448
# MSE : 26.76670164609993
# RMSE : 5.173654573519567
# R2 : 0.8342352513198357
# Adjusted R2 : 0.8327065850495863

# %%
#pred vs actual for random forest
plt.figure(figsize=(8,5))
plt.plot((np.array(y_pred_test_r_g)))
plt.plot(np.array((y_test)))
plt.legend(["Predicted","Actual"])
plt.show()

# %%
# for the important features
rf_optimal_model.feature_importances_
# Out:
# array([3.17803445e-01, 1.47536395e-01, 1.79565442e-04, 1.22029939e-03,
#        6.53678992e-03, 2.24983849e-02, 3.21035003e-04, 9.11591309e-04,
#        4.75273866e-03, 8.32876670e-04, 7.46583487e-02, 2.94541172e-03,
#        4.31538604e-03, 2.25295573e-01, 4.71732789e-04, 1.89720426e-01])

# %%
#important feature selection
importance_rf_gd=rf_optimal_model.feature_importances_
imortance_rf_gddict={"Feature":list(X_train.columns),"Feature importance":importance_rf_gd}
imortance_rf_gddf=pd.DataFrame(imortance_rf_gddict)

# %%
imortance_rf_gddf['Feature importance'] = round(imortance_rf_gddf['Feature importance'],2)

# %%
#reading table of important features
imortance_rf_gddf.head()
# Out:
#            Feature  Feature importance
# 0             Hour                0.32
# 1         Humidity                0.15
# 2       Wind_speed                0.00
# 3       Visibility                0.00
# 4  Solar_Radiation                0.01

# %%
#featuer in ascending order
imortance_rf_gddf.sort_values(by=["Feature importance"],ascending=False)
# Out:
#                     Feature  Feature importance
# 0                      Hour                0.32
# 13           Seasons_Winter                0.23
# 15      Functioning_Day_Yes                0.19
# 1                  Humidity                0.15
# 10  Temperature_and_DP_Temp                0.07
# 5                  Rainfall                0.02
# 4           Solar_Radiation                0.01
# 2                Wind_speed                0.00
# 3                Visibility                0.00
# 6                  Snowfall                0.00
# 7                      Year                0.00
# 8                       Day                0.00
# 9                     Month                0.00
# 11           Seasons_Spring                0.00
# 12           Seasons_Summer                0.00
# 14       Holiday_No Holiday                0.00

# %%
rf_optimal_model.fit(X_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=8, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=40,
#                       min_samples_split=50, min_weight_fraction_leaf=0.0,
#                       n_estimators=80, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
features=X_train.columns
importance_rfgd=rf_optimal_model.feature_importances_
indices=np.argsort(importance_rfgd)

# %%
#barh plot for important features 
plt.title("feature imporance")
plt.barh(range(len(indices)),importance_rfgd[indices],color="green",align="center")

plt.yticks(range(len(indices)),[features[i] for i in indices])
plt.xlabel("Relative importance") 
plt.show()

# %% [markdown]
# # Implementing Gradient Boosting Regression

# %%
# gradient boosting model import
gbd_model=GradientBoostingRegressor()
gbd_model.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
# Making predictions on train and test data

y_pred_train_gb = gbd_model.predict(X_train)
y_pred_test_gb = gbd_model.predict(X_test)

# %%
# for train data set
print("Model Score:",gbd_model.score(X_train,y_train))
MSE= mean_squared_error(y_train, y_pred_train_gb)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)

r2= r2_score(y_train, y_pred_train_gb)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_train, y_pred_train_gb))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# Model Score: 0.883539068956644
# MSE : 17.86155988357657
# RMSE : 4.226293870943734
# R2 : 0.883539068956644
# Adjusted R2 : 0.8824650776617197

# %%
# for test data set
print("Model Score:",gbd_model.score(X_train,y_train))
MSE= mean_squared_error(y_test, y_pred_test_gb)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)

r2= r2_score((y_test), (y_pred_test_gb))
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score((y_test), (y_pred_test_gb)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# Model Score: 0.883539068956644
# MSE : 20.39808188112455
# RMSE : 4.516423571934385
# R2 : 0.8736757721855992
# Adjusted R2 : 0.8725108225342848

# %%
#pred vs actual for Gradient boosting
plt.figure(figsize=(8,5))
plt.plot((np.array(y_pred_test_gb)))
plt.plot(np.array((y_test)))
plt.legend(["Predicted","Actual"])
plt.show()

# %%
#Heteroscedasticity
plt.scatter((y_pred_test_gb),(y_test)-(y_pred_test_gb))

# %% [markdown]
# feature importance

# %%
#feature importance
gbd_model.feature_importances_
# Out:
# array([0.26789741, 0.11498501, 0.00043032, 0.00188969, 0.02897849,
#        0.06974424, 0.00049725, 0.00036667, 0.00902429, 0.00496772,
#        0.190921  , 0.00209953, 0.00458441, 0.11376792, 0.00207427,
#        0.18777177])

# %%
#creating a data frame for important features
importances_gb = gbd_model.feature_importances_

importance_dictgb = {'Feature' : list(X_train.columns),
                   'Feature Importance' : importances_gb}

importance_dfgb = pd.DataFrame(importance_dictgb)

# %%
importance_dfgb['Feature Importance'] = round(importance_dfgb['Feature Importance'],2)

# %%
#reading the important features
importance_dfgb.head()
# Out:
#            Feature  Feature Importance
# 0             Hour                0.27
# 1         Humidity                0.11
# 2       Wind_speed                0.00
# 3       Visibility                0.00
# 4  Solar_Radiation                0.03

# %%
importance_dfgb.sort_values(by=['Feature Importance'],ascending=False)
# Out:
#                     Feature  Feature Importance
# 0                      Hour                0.27
# 10  Temperature_and_DP_Temp                0.19
# 15      Functioning_Day_Yes                0.19
# 1                  Humidity                0.11
# 13           Seasons_Winter                0.11
# 5                  Rainfall                0.07
# 4           Solar_Radiation                0.03
# 8                       Day                0.01
# 2                Wind_speed                0.00
# 3                Visibility                0.00
# 6                  Snowfall                0.00
# 7                      Year                0.00
# 9                     Month                0.00
# 11           Seasons_Spring                0.00
# 12           Seasons_Summer                0.00
# 14       Holiday_No Holiday                0.00

# %%
gbd_model.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
features = X_train.columns
importances =gbd_model.feature_importances_
indices = np.argsort(importances)

# %%
#plot the feature importance
plt.title('Feature Importance')
plt.barh(range(len(indices)), importances[indices], color='red', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')

plt.show()

# %% [markdown]
# # Training Gradient Regressor with GridsearchCV

# %%
# Create an instance of the GradientBoostingRegressor
gb_model = GradientBoostingRegressor()

# Grid search
gb_grid = GridSearchCV(estimator=gb_model,
                       param_grid = param_dict,
                       cv = 5, verbose=2)

gb_grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.6s remaining:    0.0s
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.0s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.2s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.7s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.4s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   1.3s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   1.7s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   2.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   2.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   2.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   2.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   2.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   2.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.7s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   2.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   1.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   1.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   2.0s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100

# %%
gb_grid.best_estimator_

# %%
gb_optimal_model = gb_grid.best_estimator_

# %%
gb_grid.best_params_

# %%
# Making predictions on train and test data

y_pred_train_gd_g = gb_optimal_model.predict(X_train)
y_pred_test_gd_g= gb_optimal_model.predict(X_test)

# %%
#gd with grid cv train performance
print("Model Score:",gb_optimal_model.score(X_train,y_train))
MSE= mean_squared_error(y_train, y_pred_train_gd_g)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)

r2= r2_score(y_train, y_pred_train_gd_g)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_train, y_pred_train_gd_g))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )

# %%
#metrics for rf score with gd for train
from sklearn.metrics import mean_squared_error
print("Model Score:",gb_optimal_model.score(X_train,y_train))

MSE= mean_squared_error(y_test, y_pred_test_gd_g)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)


from sklearn.metrics import r2_score
r2= r2_score(y_test, y_pred_test_gd_g)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_test, y_pred_test_gd_g))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )

# %%
#pred vs actual for Gradient boosting
plt.figure(figsize=(8,5))
plt.plot((np.array(y_pred_test_gd_g)))
plt.plot(np.array((y_test)))
plt.legend(["Predicted","Actual"])
plt.show()

# %% [markdown]
# # **Implementing Xgboost Regressor**

# %%
# Create an instance of the RandomForestRegressor
import xgboost as xgb
xg_model = xgb.XGBRegressor()


xg_model.fit(X_train,y_train)

# %%
# Making predictions on train and test data

y_pred_train_xg = xg_model.predict(X_train)
y_pred_test_xg = xg_model.predict(X_test)

# %%
#xg boost on train data
print("Model Score:",xg_model.score(X_train,y_train))
MSE= mean_squared_error(y_train, y_pred_train_xg)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)

r2= r2_score(y_train, y_pred_train_xg)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_train, y_pred_train_xg))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# Model Score: 0.8802274395883487
# MSE : 18.3694629695651
# RMSE : 4.285961148863239
# R2 : 0.8802274395883487
# Adjusted R2 : 0.8791229087718724

# %%
#Xg boost for test
MSE= mean_squared_error(y_test, y_pred_test_xg)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)

r2= r2_score((y_test), (y_pred_test_xg))
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score((y_test), (y_pred_test_xg)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# MSE : 21.012567484151045
# RMSE : 4.583946714802763
# R2 : 0.8698702957806231
# Adjusted R2 : 0.868670252398773

# %%
#Heteroscedasticity
plt.scatter((y_pred_test_xg),(y_test)-(y_pred_test_xg))

# %% [markdown]
# Feature  importance selction

# %%
xg_model.feature_importances_
# Out:
# array([0.06851235, 0.06226207, 0.00113145, 0.00563223, 0.04412329,
#        0.08109905, 0.00537752, 0.00349902, 0.00977364, 0.0102376 ,
#        0.07346597, 0.00788979, 0.04413204, 0.3727903 , 0.00834093,
#        0.20173274], dtype=float32)

# %%
importances = xg_model.feature_importances_

importance_dictxg = {'Feature' : list(X_train.columns),
                   'Feature Importance' : importances}

importance_dfxg = pd.DataFrame(importance_dictxg)

# %%
importance_dfxg['Feature Importance'] = round(importance_dfxg['Feature Importance'],2)

# %%
xg_model.fit(X_train,y_train)
# Out:
# [06:26:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
features = X_train.columns
importances = xg_model.feature_importances_
indices = np.argsort(importances)

# %%
plt.title('Feature Importance')
plt.barh(range(len(indices)), importances[indices], color='red', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')

plt.show()

# %% [markdown]
# # **Training Xgboost regressor with Gridsearch**

# %% [markdown]
# # Provide the range for  Hyperparameter

# %%
# Number of trees
n_estimators = [50,80,100]

# Maximum depth of trees
max_depth = [4,6,8]

# Minimum number of samples required to split a node
min_samples_split = [50,100,150]

# Minimum number of samples required at each leaf node
min_samples_leaf = [40,50]

# HYperparameter Grid
param_dict_xgb = {'n_estimators' : n_estimators,
              'max_depth' : max_depth,
              'min_samples_split' : min_samples_split,
              'min_samples_leaf' : min_samples_leaf,'learning_rate': [0.1, 0.05, 0.01, 0.005]}

# %%
import xgboost as xgb
xg_model = xgb.XGBRegressor()


xg_model.fit(X_train,y_train)
# Out:
# [06:26:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#              silent=None, subsample=1, verbosity=1)

# %%
# Grid search
xg_grid = GridSearchCV(estimator=xg_model,
                       param_grid = param_dict,
                       cv = 5, verbose=2)

xg_grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [06:26:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [06:26:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [06:26:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [06:26:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [06:26:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [06:26:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [06:26:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [06:26:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [06:26:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [06:26:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [06:26:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [06:26:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [06:26:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [06:26:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [06:26:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [06:26:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [06:26:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [06:26:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [06:26:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [06:26:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [06:26:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [06:26:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [06:26:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [06:26:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [06:26:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [06:26:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [06:26:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [06:26:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [06:26:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [06:26:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [06:26:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [06:26:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [06:26:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [06:26:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.2s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [06:26:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [06:26:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [06:26:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [06:26:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [06:26:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [06:26:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [06:26:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [06:26:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [06:26:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [06:26:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [06:26:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:26:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:26:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:26:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:26:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:26:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:26:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:26:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:26:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:26:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:26:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:26:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:26:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:26:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:26:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:26:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:26:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.2s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:26:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:26:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:26:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.2s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:26:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.2s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:26:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:26:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:26:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:26:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:26:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [06:26:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [06:26:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [06:26:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [06:26:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [06:26:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [06:26:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [06:26:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [06:26:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [06:26:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [06:26:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.3s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [06:26:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [06:26:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [06:26:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [06:26:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [06:26:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.4s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [06:26:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [06:26:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [06:26:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [06:26:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   0.5s
# [CV] max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [06:26:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=4, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   0.5s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [06:26:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [06:26:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [06:26:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [06:26:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50
# [06:26:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [06:26:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [06:26:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [06:26:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [06:26:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80
# [06:26:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [06:26:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [06:27:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.7s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [06:27:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [06:27:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.7s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100
# [06:27:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=50, n_estimators=100, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [06:27:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [06:27:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [06:27:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [06:27:04] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50
# [06:27:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [06:27:05] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [06:27:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [06:27:06] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [06:27:07] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80
# [06:27:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [06:27:08] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [06:27:09] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.7s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [06:27:10] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.7s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [06:27:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.7s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100
# [06:27:11] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=100, n_estimators=100, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [06:27:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [06:27:12] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [06:27:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [06:27:13] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50
# [06:27:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [06:27:14] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [06:27:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [06:27:15] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [06:27:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80
# [06:27:16] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [06:27:17] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [06:27:18] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.7s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [06:27:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [06:27:19] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.7s
# [CV] max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [06:27:20] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:27:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:27:21] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:27:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:27:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:27:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:27:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:27:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:27:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:27:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:27:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:27:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:27:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.7s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:27:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:27:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.7s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:27:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   0.8s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:27:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:27:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:27:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:27:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:27:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.4s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:27:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:27:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:27:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:27:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.6s
# [CV] max_depth=6, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# ...
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [06:28:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [06:28:23] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100
# [06:28:24] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=40, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:28:25] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:28:26] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:28:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:28:27] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50
# [06:28:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:28:28] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:28:29] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:28:30] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:28:31] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80
# [06:28:32] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:28:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:28:34] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:28:35] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:28:36] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100
# [06:28:37] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=50, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:28:38] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:28:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:28:39] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:28:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50
# [06:28:40] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:28:41] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:28:42] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:28:43] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:28:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80
# [06:28:44] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [06:28:45] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [06:28:46] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [06:28:47] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [06:28:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100
# [06:28:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=100, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [06:28:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [06:28:51] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [06:28:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [06:28:52] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50
# [06:28:53] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=50, total=   0.6s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [06:28:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [06:28:54] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [06:28:55] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [06:28:56] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80
# [06:28:57] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=80, total=   0.9s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [06:28:58] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [06:28:59] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [06:29:00] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [06:29:01] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [CV] max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100
# [06:29:02] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [CV]  max_depth=8, min_samples_leaf=50, min_samples_split=150, n_estimators=100, total=   1.1s
# [06:29:03] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [Parallel(n_jobs=1)]: Done 270 out of 270 | elapsed:  2.7min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=XGBRegressor(base_score=0.5, booster='gbtree',
#                                     colsample_bylevel=1, colsample_bynode=1,
#                                     colsample_bytree=1, gamma=0,
#                                     importance_type='gain', learning_rate=0.1,
#                                     max_delta_step=0, max_depth=3,
#                                     min_child_weight=1, missing=None,
#                                     n_estimators=100, n_jobs=1, nthread=None,
#                                     objective='reg:linear', random_state=0,
#                                     reg_alpha=0, reg_lambda=1,
#                                     scale_pos_weight=1, seed=None, silent=None,
#                                     subsample=1, verbosity=1),
#              iid='deprecated', n_jobs=None,
#              param_grid={'max_depth': [4, 6, 8], 'min_samples_leaf': [40, 50],
#                          'min_samples_split': [50, 100, 150],
#                          'n_estimators': [50, 80, 100]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=2)

# %%
xg_grid.best_estimator_

# %%
xg_optimal_model = xg_grid.best_estimator_

# %%
xg_grid.best_params_

# %%
# Making predictions on train and test data

y_pred_train_x_g = xg_optimal_model.predict(X_train)
y_pred_test_x_g  = xg_optimal_model.predict(X_test)

# %%
#xg after training score for train data
print("Model Score:",xg_optimal_model.score(X_train,y_train))
MSE= mean_squared_error(y_train, y_pred_train_x_g)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)
r2= r2_score(y_train, y_pred_train_x_g)
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score(y_train, y_pred_train_x_g))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )

# %%
#Xg boost  after training for test
print("Model Score:",xg_optimal_model.score(X_train,y_train))
MSE= mean_squared_error(y_test, y_pred_test_x_g)
print("MSE :",MSE)

RMSE=np.sqrt(MSE)
print("RMSE :",RMSE)

r2= r2_score((y_test), (y_pred_test_x_g))
print("R2 :",r2)
print("Adjusted R2 :",1-(1-r2_score((y_test), (y_pred_test_x_g)))*((X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1)) )
# Out:
# Model Score: 0.9770309205417013
# MSE : 13.00960734058643
# RMSE : 3.6068833278311665
# R2 : 0.9194321990152959
# Adjusted R2 : 0.9186892106488664

# %%
plt.figure(figsize=(8,5))
plt.plot((y_pred_test_x_g))
plt.plot(np.array((y_test)))
plt.legend(["Predicted","Actual"])
plt.show()

# %%
### Heteroscadacity
plt.scatter((y_pred_test_x_g),(y_test)-(y_pred_test_x_g))

# %% [markdown]
# # Features importance with XGBOOST training

# %%
xg_optimal_model.feature_importances_
# Out:
# array([0.03007521, 0.01762952, 0.00109576, 0.0016186 , 0.0064221 ,
#        0.02655201, 0.00266114, 0.00265166, 0.00289786, 0.00309629,
#        0.01372509, 0.01248075, 0.00401535, 0.56509805, 0.00490237,
#        0.30507818], dtype=float32)

# %%
importances = xg_optimal_model.feature_importances_

importance_dictxgt = {'Feature' : list(X_train.columns),
                   'Feature Importance' : importances}

importance_dfxgt = pd.DataFrame(importance_dictxgt)

# %%
importance_dfxgt['Feature Importance'] = round(importance_dfxgt['Feature Importance'],2)

# %%
importance_dfxgt.head()
# Out:
#            Feature  Feature Importance
# 0             Hour                0.03
# 1         Humidity                0.02
# 2       Wind_speed                0.00
# 3       Visibility                0.00
# 4  Solar_Radiation                0.01

# %%
importance_dfxgt.sort_values(by=['Feature Importance'],ascending=False)
# Out:
#                     Feature  Feature Importance
# 13           Seasons_Winter                0.57
# 15      Functioning_Day_Yes                0.31
# 0                      Hour                0.03
# 5                  Rainfall                0.03
# 1                  Humidity                0.02
# 4           Solar_Radiation                0.01
# 10  Temperature_and_DP_Temp                0.01
# 11           Seasons_Spring                0.01
# 2                Wind_speed                0.00
# 3                Visibility                0.00
# 6                  Snowfall                0.00
# 7                      Year                0.00
# 8                       Day                0.00
# 9                     Month                0.00
# 12           Seasons_Summer                0.00
# 14       Holiday_No Holiday                0.00

# %%
features = X_train.columns
importances = xg_optimal_model.feature_importances_
indices = np.argsort(importances)

# %%
plt.title('Feature Importance')
plt.barh(range(len(indices)), importances[indices], color='red', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')

plt.show()

# %% [markdown]
# # Model Summary for the train data set

# %%
from prettytable import PrettyTable
train = PrettyTable(['SL NO',"MODEL_NAME", "Train MSE", "Train RMSE",'Train R^2','Train Adjusted R^2'])
train.add_row(['1','Linear Regression','52.95555328513579',' 7.277056636108846','0.6547192361864398',' 0.651535090814095'])
train.add_row(['2','lasso Regression','54.64834166119503','7.392451667829492','0.6436819185266032','0.6403959880922664'])
train.add_row(['3','Ridge Regression','52.955560208927636','7.277057111836325','0.6547191910419368','0.6515350452532745'])
train.add_row(['4','Elastic net regressor','64.38876290053423','8.024260894346234','0.5801724303474118','0.5763008216359182'])
train.add_row(['5','Decision Tree regressor','28.409014527459313','5.330010743653273','0.8147675621022166','.8130593667094993'])
train.add_row(['6','Random forest regressor','24.007196716801857','4.899713942344171','0.8434682917055565','0.842024771629066'])
train.add_row(['7','Gradient Boost','8.001689449028063','2.8287257641963217','0.9478273897001314','0.9473462589999597'])
train.add_row(['8','XGBoost','3.522757241759442','1.8769009674885466','0.9770309205417014','0.9768191019415096'])
print(train)
# Out:
# +-------+-------------------------+--------------------+--------------------+--------------------+--------------------+
# | SL NO |        MODEL_NAME       |     Train MSE      |     Train RMSE     |     Train R^2      | Train Adjusted R^2 |
# +-------+-------------------------+--------------------+--------------------+--------------------+--------------------+
# |   1   |    Linear Regression    | 52.95555328513579  |  7.277056636108846 | 0.6547192361864398 |  0.651535090814095 |
# |   2   |     lasso Regression    | 54.64834166119503  | 7.392451667829492  | 0.6436819185266032 | 0.6403959880922664 |
# |   3   |     Ridge Regression    | 52.955560208927636 | 7.277057111836325  | 0.6547191910419368 | 0.6515350452532745 |
# |   4   |  Elastic net regressor  | 64.38876290053423  | 8.024260894346234  | 0.5801724303474118 | 0.5763008216359182 |
# |   5   | Decision Tree regressor | 28.409014527459313 | 5.330010743653273  | 0.8147675621022166 | .8130593667094993  |
# |   6   | Random forest regressor | 24.007196716801857 | 4.899713942344171  | 0.8434682917055565 | 0.842024771629066  |
# |   7   |      Gradient Boost     | 8.001689449028063  | 2.8287257641963217 | 0.9478273897001314 | 0.9473462589999597 |
# |   8   |         XGBoost         | 3.522757241759442  | 1.8769009674885466 | 0.9770309205417014 | 0.9768191019415096 |
# +-------+-------------------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# # Model Summary for the test data set

# %%
from prettytable import PrettyTable
test = PrettyTable(['SL NO',"MODEL_NAME", "Test MSE", "Test RMSE",'Test R^2','Test Adjusted R^2'])
test.add_row(['1','Linear Regression','55.08739505098533','7.4220883214217634','0.6588467149667641','0.6557006327993107'])
test.add_row(['2','lasso Regression', '57.49564641514416','7.582588371733241','0.643932543343507','0.6406489241466748'])
test.add_row(['3','Ridge Regression','55.08773606712857','7.422111294445036','0.6588446030720665','0.655698501428'])
test.add_row(['4','Elastic net regressor','67.17969621593292','8.196322115188796','0.5839597419629589','0.5801230594680928'])
test.add_row(['5','Decision Tree regressor','32.217717802173574','5.676065345128928','0.8004774004232265','0.7986374225596943'])
test.add_row(['6','Random forest regressor','26.998863153577467','5.196043028457084','0.8327974875471809','0.8312555623602961'])
test.add_row(['7','Gradient Boost','14.1788868387969','3.7654862685710233','0.9121909137527177','0.9113811469631173'])
test.add_row(['8','XGBoost','13.00960734058643','3.6068833278311665','0.9194321990152959','0.9186892106488664'])
print(test)
# Out:
# +-------+-------------------------+--------------------+--------------------+--------------------+--------------------+
# | SL NO |        MODEL_NAME       |      Test MSE      |     Test RMSE      |      Test R^2      | Test Adjusted R^2  |
# +-------+-------------------------+--------------------+--------------------+--------------------+--------------------+
# |   1   |    Linear Regression    | 55.08739505098533  | 7.4220883214217634 | 0.6588467149667641 | 0.6557006327993107 |
# |   2   |     lasso Regression    | 57.49564641514416  | 7.582588371733241  | 0.643932543343507  | 0.6406489241466748 |
# |   3   |     Ridge Regression    | 55.08773606712857  | 7.422111294445036  | 0.6588446030720665 |   0.655698501428   |
# |   4   |  Elastic net regressor  | 67.17969621593292  | 8.196322115188796  | 0.5839597419629589 | 0.5801230594680928 |
# |   5   | Decision Tree regressor | 32.217717802173574 | 5.676065345128928  | 0.8004774004232265 | 0.7986374225596943 |
# |   6   | Random forest regressor | 26.998863153577467 | 5.196043028457084  | 0.8327974875471809 | 0.8312555623602961 |
# |   7   |      Gradient Boost     |  14.1788868387969  | 3.7654862685710233 | 0.9121909137527177 | 0.9113811469631173 |
# |   8   |         XGBoost         | 13.00960734058643  | 3.6068833278311665 | 0.9194321990152959 | 0.9186892106488664 |
# +-------+-------------------------+--------------------+--------------------+--------------------+--------------------+
# +-------+-------------------------+--------------------+--------------------+--------------------+--------------------+
# | SL NO |        MODEL_NAME       |      Test MSE      |     Test RMSE      |      Test R^2      | Test Adjusted R^2  |
# +-------+-------------------------+--------------------+--------------------+--------------------+--------------------+
# |   1   |    Linear Regression    | 55.08739505098533  | 7.4220883214217634 | 0.6588467149667641 | 0.6557006327993107 |
# |   2   |     lasso Regression    | 57.49564641514416  | 7.582588371733241  | 0.643932543343507  | 0.6406489241466748 |
# |   3   |     Ridge Regression    | 55.08773606712857  | 7.422111294445036  | 0.6588446030720665 |   0.655698501428   |
# |   4   |  Elastic net regressor  | 67.17969621593292  | 8.196322115188796  | 0.5839597419629589 | 0.5801230594680928 |
# |   5   | Decision Tree regressor | 32.217717802173574 | 5.676065345128928  | 0.8004774004232265 | 0.7986374225596943 |
# |   6   | Random forest regressor | 26.998863153577467 | 5.196043028457084  | 0.8327974875471809 | 0.8312555623602961 |
# |   7   |      Gradient Boost     |  14.1788868387969  | 3.7654862685710233 | 0.9121909137527177 | 0.9113811469631173 |
# |   8   |         XGBoost         | 13.00960734058643  | 3.6068833278311665 | 0.9194321990152959 | 0.9186892106488664 |
# +-------+-------------------------+--------------------+--------------------+--------------------+--------------------+

# %% [markdown]
# # **What gets measured, gets managed. - Peter Drucker**

# %% [markdown]
# # Conclusion:
# * As it was stated in the problem, rented bike count was low in 2017 untill november. That is when business took off and rented bike count started increasing.
#
# * There was sharp increase in demand from the end of 2017 that too in winter season of the year. The demand however decrease at the end of 2018.
#
# * bike count rent is highly correlated with 'Hour', which seems obvious. Demand for bike is mostly in morning (7 to 8) and in the evening (3 to 9).
#
# * After doing exploratory data analysis, applying Linear Regression model didn't go quite well as it gave only 65% accuracy.
#
#
# * Lasso and Ridge Regression helps to reduce model complexity and prevent over-fitting which may result from simple linear regression. with Lasso, ridge and ElsasticNet regressor We got r squared value of 0.64, 0.65, 0.58 respectively.
#
#
# * With Decision tree we reached at the model r squared value of 0.80.
#
# * Random forest regressor gave r squared value of 0.83 on test data.
#
# * Gradient Boost gave r squared value of 0.91.
#
# * XGBOOST came for the rescue to help us get best accuracy to approximate numbers of rented bikes demand. It gave amazing results of training r-square at 0.97 and test r-square value at 0.919 also with adjusted r-square with 0.918.
